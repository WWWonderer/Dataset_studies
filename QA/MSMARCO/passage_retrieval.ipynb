# %% [markdown]
# <a href="https://colab.research.google.com/github/WWWonderer/Dataset_studies/blob/main/QA/MSMARCO/passage_retrieval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Download data (this section may take a lot of time... 5min download via azcopy, 3min tar, 19min gzip on colab platform)

# %%
# !wget -O azcopy_v10.tar.gz https://aka.ms/downloadazcopy-v10-linux && tar -xf azcopy_v10.tar.gz --strip-components=1
# Out:
# --2023-08-11 23:57:44--  https://aka.ms/downloadazcopy-v10-linux
# Resolving aka.ms (aka.ms)... 2.19.147.45
# Connecting to aka.ms (aka.ms)|2.19.147.45|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://azcopyvnext.azureedge.net/releases/release-10.20.1-20230809/azcopy_linux_amd64_10.20.1.tar.gz [following]
# --2023-08-11 23:57:45--  https://azcopyvnext.azureedge.net/releases/release-10.20.1-20230809/azcopy_linux_amd64_10.20.1.tar.gz
# Resolving azcopyvnext.azureedge.net (azcopyvnext.azureedge.net)... 23.40.99.136, 23.40.99.147, 2600:1407:3c00:29::1721:1d12, ...
# Connecting to azcopyvnext.azureedge.net (azcopyvnext.azureedge.net)|23.40.99.136|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14547941 (14M) [application/gzip]
# Saving to: ‘azcopy_v10.tar.gz’
#
# azcopy_v10.tar.gz   100%[===================>]  13.87M  61.3MB/s    in 0.2s
#
# ...

# %%
# !./azcopy --version
# Out:
# azcopy version 10.20.1

# %%
# !./azcopy copy https://msmarco.blob.core.windows.net/msmarcoranking/msmarco_v2_doc.tar msmarco_v2_doc.tar
# Out:
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job 51557d91-6852-b944-4c25-8058e37d1cad has started
# Log file is located at: /root/.azcopy/51557d91-6852-b944-4c25-8058e37d1cad.log
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total, 2-sec Throughput (Mb/s): 116.2382
#
#
# Job 51557d91-6852-b944-4c25-8058e37d1cad summary
# Elapsed Time (Minutes): 5.14
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 34648862720
# Final Job Status: Completed

# %%
# !tar -xf msmarco_v2_doc.tar

# %%
# %%bash
# cd /content/msmarco_v2_doc
# for file in *.gz; do
#   gzip -d "$file"
# done

# %% [markdown]
# #Viewing Data Structure

# %%
# !head msmarco_v2_doc/msmarco_doc_00
# Out:
# {"url": "http://0-60.reviews/0-60-times/", "title": "0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews", "headings": "0-60 Times\n0-60 Times", "body": "0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews\n0-60 Times\nThere are many ways to measure the power a vehicle has \u2013 top speed, horsepower, foot-pounds of torque. Those are all important, but the most asked question is, \u201cWhat\u2019s the 0-60 time?\u201d This is nothing more than a measure of how quickly a vehicle can reach the 60 mile per hour mark. It is a measure of acceleration of a vehicle. 0-60 times differ a great deal depending on the amount of power a motor puts out, of course. But anyone who spends any amount of time with car enthusiasts are sure to hear the ubiquitous term bantered around more often than most other metrics by which cars are measured in terms of power.\nThe only other measure that comes close as far as how acceleration is commonly measures in ca
# ...

# %%
# !wc -l msmarco_v2_doc/msmarco_doc_00
# Out:
# 200000 msmarco_v2_doc/msmarco_doc_00

# %%
# !head msmarco_v2_doc/msmarco_doc_01
# Out:
# {"url": "http://edmontonjournal.com/life/food/whats-the-difference-between-golden-brown-and-demerara-sugar", "title": "What\u2019s the difference between golden, brown and demerara sugar? | Edmonton Journal", "headings": "What\u2019s the difference between golden, brown and demerara sugar?\nWhat\u2019s the difference between golden, brown and demerara sugar?\nQuestion: What\u2019s the difference between golden, brown and demerara sugar?\nLatest National Stories\nEdmonton Journal Headline News\nThis Week in Flyers\n", "body": "What\u2019s the difference between golden, brown and demerara sugar? | Edmonton Journal\nShare this Story: What\u2019s the difference between golden, brown and demerara sugar?\nCopy Link\nEmail\nFacebook\nTwitter\nReddit\nPinterest\nLinkedIn\nTumblr\nBreadcrumb Trail Links\nFood\nWhat\u2019s the difference between golden, brown and demerara sugar?\nAuthor of the article:\nATCO Blue Flame Kitchen\nPublishing date:\nJul 22, 2014 \u2022 July 22, 2014 \u2022 2 minut
# ...

# %%
# !wc -l msmarco_v2_doc/msmarco_doc_01
# Out:
# 200000 msmarco_v2_doc/msmarco_doc_01

# %%
# !wc -l msmarco_v2_doc/msmarco_doc_59
# Out:
# 159635 msmarco_v2_doc/msmarco_doc_59

# %% [markdown]
# As shown above, the total number of passages can be calculated as follow:
#
#
#
# ```
# 59 * 200000 + 159635 = 11959635
# ```

# %%
import json
file_path = "msmarco_v2_doc/msmarco_doc_00"
with open(file_path,'r') as file:
  line = file.readline()
  json_data = json.loads(line)
  print(json.dumps(json_data, indent=2))
# Out:
# {
#   "url": "http://0-60.reviews/0-60-times/",
#   "title": "0-60 Times - 0-60 | 0 to 60 Times & 1/4 Mile Times | Zero to 60 Car Reviews",
#   "headings": "0-60 Times\n0-60 Times",
# ...

# %%
file_path = "msmarco_v2_doc/msmarco_doc_01"
with open(file_path,'r') as file:
  line = file.readline()
  print("first line size: ", len(line))
  print("second line: ")
  line = file.readline()
  json_data = json.loads(line)
  print(json.dumps(json_data, indent=2))
# Out:
# first line size:  5421
# second line:
# {
#   "url": "http://edmontonjournal.com/life/food/when-grilling-do-i-leave-the-lid-open-or-closed",
#   "title": "When grilling, do I leave the lid open or closed? | Edmonton Journal",
#   "headings": "When grilling, do I leave the lid open or closed?\nWhen grilling, do I leave the lid open or closed?\nQuestion: When grilling, do I leave the lid open or closed?\nLatest National Stories\nEdmonton Journal Headline News\n",
# ...

# %% [markdown]
# Document corpus is in jsonl format. Each document has:
#
# * docid: e.g. `msmarco_doc_31_726133` is in the file `msmarco_v2_doc/msmarco_doc_31` at position `726133`, where `726133` is the byte size / num of characters.
# * url
# * title
# * headings: A newline-separated list of headings that were extracted from the document, where the first heading may be a generated heading that describes the whole document (an alternate title).
# * body

# %% [markdown]
# #Quick Access Data

# %%
import json

def get_document(document_id):
    (string1, string2, bundlenum, position) = document_id.split('_')
    assert string1 == 'msmarco' and string2 == 'doc'

    with open(f'./msmarco_v2_doc/msmarco_doc_{bundlenum}', 'rt', encoding='utf8') as in_fh:
        #.seek bypasses whole file search / index, as the offset is encoded in docid
        in_fh.seek(int(position))
        json_string = in_fh.readline()
        document = json.loads(json_string)
        assert document['docid'] == document_id
        return document

# %%
document = get_document('msmarco_doc_31_726131')
for k, v in document.items():
  print(f'{k}: {v}')
# Out:
# url: https://vcahospitals.com/know-your-pet/why-cats-turn-around-before-lying-down
# title: Why Cats Turn Around Before Lying Down | VCA Animal Hospital
# headings: Why Cats Turn Around Before Lying Down
# Why Cats Turn Around Before Lying Down
# By Ryan Llera, BSc, DVM; Lynn Buzhardt, DVM
# Why do cats turn around before lying down?
# Why do cats sleep so much?
# Do cats circle before sleep for survival?
# "Cats effectively created a safe place to sleep by circling and making a bed."
# Does circling help cats get comfortable?
# What does a pet cat's sleep preparation ritual look like?
# What if the circling becomes excessive?
#
# body: Why Cats Turn Around Before Lying Down | VCA Animal Hospital
# ...

# %% [markdown]
# #Training data

# %%
# !wget -O train_queries.tsv https://msmarco.blob.core.windows.net/msmarcoranking/passv2_train_queries.tsv
# Out:
# --2023-08-12 04:57:32--  https://msmarco.blob.core.windows.net/msmarcoranking/passv2_train_queries.tsv
# Resolving msmarco.blob.core.windows.net (msmarco.blob.core.windows.net)... 20.150.34.4
# Connecting to msmarco.blob.core.windows.net (msmarco.blob.core.windows.net)|20.150.34.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11608838 (11M) [application/octet-stream]
# Saving to: ‘train_queries.tsv’
#
# train_queries.tsv   100%[===================>]  11.07M  8.42MB/s    in 1.3s
#
# 2023-08-12 04:57:33 (8.42 MB/s) - ‘train_queries.tsv’ saved [11608838/11608838]

# %%
# !wc -l train_queries.tsv
# Out:
# 277144 train_queries.tsv

# %%
# !head train_queries.tsv
# Out:
# 121352	define extreme
# 510633	tattoo fixers how much does it cost
# 674172	what is a bank transit number
# 570009	what are the four major groups of elements
# 54528	blood clots in urine after menopause
# 507001	symptoms of an enlarged heart in dogs
# 466926	number of times congress voted to repeal aca
# 224811	how does a firefly light up
# 918533	what was introduced to the human diet in what year
# 80926	can you use wallapop on your computer

# %% [markdown]
# train queries has `qid` and `query`

# %%
# !./azcopy copy https://msmarco.blob.core.windows.net/msmarcoranking/passv2_train_top100.txt.gz passv2_train_top100.txt.gz && gzip -d passv2_train_top100.txt.gz
# Out:
# INFO: Scanning...
# INFO: Autologin not specified.
# INFO: Any empty folders will not be processed, because source and/or destination doesn't have full folder support
#
# Job bc252201-faeb-284e-484f-b4b1f33b00f3 has started
# Log file is located at: /root/.azcopy/bc252201-faeb-284e-484f-b4b1f33b00f3.log
#
# 100.0 %, 1 Done, 0 Failed, 0 Pending, 0 Skipped, 1 Total,
#
#
# Job bc252201-faeb-284e-484f-b4b1f33b00f3 summary
# Elapsed Time (Minutes): 0.1
# Number of File Transfers: 1
# Number of Folder Property Transfers: 0
# Number of Symlink Transfers: 0
# Total Number of Transfers: 1
# Number of File Transfers Completed: 1
# Number of Folder Transfers Completed: 0
# Number of File Transfers Failed: 0
# Number of Folder Transfers Failed: 0
# Number of File Transfers Skipped: 0
# Number of Folder Transfers Skipped: 0
# TotalBytesTransferred: 340634991
# Final Job Status: Completed

# %%
# !wc -l passv2_train_top100.txt
# Out:
# 27713673 passv2_train_top100.txt

# %%
# !head -n 101 passv2_train_top100.txt
# Out:
# 5 Q0 msmarco_passage_49_25899182 1 12.127800 Anserini
# 5 Q0 msmarco_passage_06_781809452 2 11.942800 Anserini
# 5 Q0 msmarco_passage_09_146319807 3 11.770300 Anserini
# 5 Q0 msmarco_passage_18_567713921 4 11.588300 Anserini
# 5 Q0 msmarco_passage_30_434058059 5 11.588299 Anserini
# 5 Q0 msmarco_passage_39_274709263 6 11.531900 Anserini
# 5 Q0 msmarco_passage_65_807511329 7 11.512900 Anserini
# 5 Q0 msmarco_passage_66_132124624 8 11.512899 Anserini
# 5 Q0 msmarco_passage_65_453740470 9 11.410800 Anserini
# 5 Q0 msmarco_passage_53_503988399 10 11.298600 Anserini
# 5 Q0 msmarco_passage_24_96464440 11 11.163500 Anserini
# 5 Q0 msmarco_passage_07_139264556 12 11.152600 Anserini
# 5 Q0 msmarco_passage_50_18716141 13 11.152599 Anserini
# 5 Q0 msmarco_passage_65_465317585 14 11.121700 Anserini
# 5 Q0 msmarco_passage_00_619729852 15 11.116700 Anserini
# 5 Q0 msmarco_passage_10_633458392 16 11.116699 Anserini
# 5 Q0 msmarco_passage_15_400152829 17 11.116698 Anserini
# ...

# %% [markdown]
# passv2_train_top100 has `qid`, `Q0`, `docid`, `rank`, `score`, `runstring`

# %%
# !wget -O passv2_train_qrels.tsv https://msmarco.blob.core.windows.net/msmarcoranking/passv2_train_qrels.tsv
# Out:
# --2023-08-12 05:16:41--  https://msmarco.blob.core.windows.net/msmarcoranking/passv2_train_qrels.tsv
# Resolving msmarco.blob.core.windows.net (msmarco.blob.core.windows.net)... 20.150.34.4
# Connecting to msmarco.blob.core.windows.net (msmarco.blob.core.windows.net)|20.150.34.4|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11620946 (11M) [application/octet-stream]
# Saving to: ‘passv2_train_qrels.tsv’
#
# passv2_train_qrels. 100%[===================>]  11.08M  8.44MB/s    in 1.3s
#
# 2023-08-12 05:16:43 (8.44 MB/s) - ‘passv2_train_qrels.tsv’ saved [11620946/11620946]

# %%
# !wc -l passv2_train_qrels.tsv
# Out:
# 284212 passv2_train_qrels.tsv

# %%
# !head passv2_train_qrels.tsv
# Out:
# 1185869	0	msmarco_passage_08_840101254	1
# 1183785	0	msmarco_passage_01_444503625	1
# 695572	0	msmarco_passage_20_461843390	1
# 852919	0	msmarco_passage_00_837399976	1
# 637313	0	msmarco_passage_08_12770678	1
# 608175	0	msmarco_passage_07_542886332	1
# 416310	0	msmarco_passage_00_714145216	1
# 645590	0	msmarco_passage_61_310962365	1
# 313342	0	msmarco_passage_00_494777959	1
# 186154	0	msmarco_passage_02_556351008	1

# %% [markdown]
# passv2_train_qrels has `qid`, `0`, `docid`, `1`
